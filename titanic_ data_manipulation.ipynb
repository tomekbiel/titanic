# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# <h3>Capturing a list of Column Names

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# <h3>Looking at datatypes of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %% [markdown]
# <h3>Selecting a subset of columns

# %%
df[[ 'sex', 'age', 'sibsp', 'parch', 'fare', 'class', 'deck', 'embark_town', 'alive']]
# Out:
#         sex   age  sibsp  parch     fare   class deck  embark_town alive
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton    no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg   yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton   yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton   yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton    no
# ..      ...   ...    ...    ...      ...     ...  ...          ...   ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton    no
# 887  female  19.0      0      0  30.0000   First    B  Southampton   yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton    no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg   yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown    no
#
# [891 rows x 9 columns]

# %% [markdown]
# <h3>Deleting Columns

# %%
df = df.drop(columns=['survived','pclass','embarked','who','adult_male','alone'])

# %%
df
# Out:
#         sex   age  sibsp  parch     fare   class deck  embark_town alive
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton    no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg   yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton   yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton   yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton    no
# ..      ...   ...    ...    ...      ...     ...  ...          ...   ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton    no
# 887  female  19.0      0      0  30.0000   First    B  Southampton   yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton    no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg   yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown    no
#
# [891 rows x 9 columns]

# %% [markdown]
# <h3>Renaming Columns

# %%
df['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df.rename(columns={'class':'pclass',
                   'alive':'survived'}, inplace=True)

# %%
df
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton       no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg      yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton      yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton      yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton       no
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton       no
# 887  female  19.0      0      0  30.0000   First    B  Southampton      yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg      yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown       no
#
# [891 rows x 9 columns]

# %% [markdown]
# <h3>Evaluating Column Values

# %%
x = 5

# %%
x == 0
# Out:
# False

# %%
df['sibsp']==0
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: sibsp, Length: 891, dtype: bool

# %% [markdown]
# <h3>Combining Statements

# %%
True & False
# Out:
# False

# %%
True & True
# Out:
# True

# %%
False & False
# Out:
# False

# %%
True | False
# Out:
# True

# %%
True | True
# Out:
# True

# %%
False | False
# Out:
# False

# %%
(df['sibsp']==0 )
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: sibsp, Length: 891, dtype: bool

# %%
(df['parch']==0)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: parch, Length: 891, dtype: bool

# %%
(df['sibsp']==0) & (df['parch']==0)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %% [markdown]
# <h3>Adding Columns

# %%
df['alone'] = (df['sibsp']==0) & (df['parch']==0)

# %%
df
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived  \
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton       no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg      yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton      yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton      yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton       no
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton       no
# 887  female  19.0      0      0  30.0000   First    B  Southampton      yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg      yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown       no
#
#      alone
# 0    False
# 1    False
# 2     True
# ...

# %%
df['sample'] = range(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-16-2009992390.py in <cell line: 0>()
# ----> 1 df['sample'] = range(200)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
# ...

# %%
df['sample'] = 7

# %%
df
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived  \
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton       no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg      yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton      yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton      yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton       no
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton       no
# 887  female  19.0      0      0  30.0000   First    B  Southampton      yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg      yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown       no
#
#      alone  sample
# 0    False       7
# ...

# %%
df['sample2'] = [1,2,3,4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-34-2270281683.py in <cell line: 0>()
# ----> 1 df['sample2'] = [1,2,3,4]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
# ...

# %% [markdown]
# <h3>Editing a Column

# %%
df['sample'] = 8

# %%
df
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived  \
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton       no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg      yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton      yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton      yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton       no
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton       no
# 887  female  19.0      0      0  30.0000   First    B  Southampton      yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg      yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown       no
#
#      alone  sample
# 0    False       8
# ...

# %% [markdown]
# <h3>Swapping the values of a column

# %%
change = {'no':0,
          'yes':1}

# %%
df['survived_num'] = df['survived'].replace(change)
# Out:
# /tmp/ipython-input-38-392700281.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['survived_num'] = df['survived'].replace(change)

# %%
df
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived  \
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton       no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg      yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton      yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton      yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton       no
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton       no
# 887  female  19.0      0      0  30.0000   First    B  Southampton      yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg      yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown       no
#
#      sample  survived_num
# 0         8             0
# ...

# %% [markdown]
# <h3>Checking for Unique Values

# %%
df['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df['embark_town'].nunique()
# Out:
# 3

# %% [markdown]
# <h3>Distribution among unique values

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# <h3>Bucketting Values of a Numeric Feature

# %%
df['age']//10*10
# Out:
# 0      20.0
# 1      30.0
# 2      20.0
# 3      30.0
# 4      30.0
#        ...
# 886    20.0
# 887    10.0
# 888     NaN
# 889    20.0
# 890    30.0
# Name: age, Length: 891, dtype: float64

# %%
df['age_bucket'] = df['age']//10*10

# %% [markdown]
# <h3>Groupby Function

# %%
df.groupby('sex').age.mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df.groupby('sex').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-43-3838006174.py in <cell line: 0>()
# ----> 1 df.groupby('sex').mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    2450             )
#    2451         else:
# -> 2452             result = self._cython_agg_general(
#    2453                 "mean",
#    2454                 alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# ...

# %%
df.groupby('sex')

# %%
df[df.sex=='male'].age.mean(), df[df.sex=='female'].age.mean()
# Out:
# (np.float64(30.72664459161148), np.float64(27.915708812260537))

# %%
df.groupby('sex').age.agg([np.min, np.mean, np.max])
# Out:
# /tmp/ipython-input-48-791662532.py:1: FutureWarning: The provided callable <function min at 0x7f54c3851b20> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('sex').age.agg([np.min, np.mean, np.max])
# /tmp/ipython-input-48-791662532.py:1: FutureWarning: The provided callable <function mean at 0x7f54c38523e0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby('sex').age.agg([np.min, np.mean, np.max])
# /tmp/ipython-input-48-791662532.py:1: FutureWarning: The provided callable <function max at 0x7f54c38519e0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
# ...

# %%
df.groupby('age_bucket').survived_num.mean()
# Out:
# age_bucket
# 0.0     0.612903
# 10.0    0.401961
# 20.0    0.350000
# 30.0    0.437126
# 40.0    0.382022
# 50.0    0.416667
# 60.0    0.315789
# 70.0    0.000000
# 80.0    1.000000
# Name: survived_num, dtype: float64

# %%
df.groupby(['sex','age_bucket']).survived_num.agg([np.mean, np.size])
# Out:
# /tmp/ipython-input-49-2248724556.py:1: FutureWarning: The provided callable <function mean at 0x7f54c38523e0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(['sex','age_bucket']).survived_num.agg([np.mean, np.size])
#                        mean  size
# sex    age_bucket
# female 0.0         0.633333    30
#        10.0        0.755556    45
#        20.0        0.722222    72
#        30.0        0.833333    60
#        40.0        0.687500    32
#        50.0        0.888889    18
#        60.0        1.000000     4
# male   0.0         0.593750    32
#        10.0        0.122807    57
#        20.0        0.168919   148
#        30.0        0.214953   107
#        40.0        0.210526    57
#        50.0        0.133333    30
#        60.0        0.133333    15
#        70.0        0.000000     6
#        80.0        1.000000     1

# %% [markdown]
# <h3>Sort a DataFrame

# %%
df.sort_values(by='age')
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived  \
# 803    male  0.42      0      1   8.5167   Third  NaN    Cherbourg      yes
# 755    male  0.67      1      1  14.5000  Second  NaN  Southampton      yes
# 644  female  0.75      2      1  19.2583   Third  NaN    Cherbourg      yes
# 469  female  0.75      2      1  19.2583   Third  NaN    Cherbourg      yes
# 78     male  0.83      0      2  29.0000  Second  NaN  Southampton      yes
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 859    male   NaN      0      0   7.2292   Third  NaN    Cherbourg       no
# 863  female   NaN      8      2  69.5500   Third  NaN  Southampton       no
# 868    male   NaN      0      0   9.5000   Third  NaN  Southampton       no
# 878    male   NaN      0      0   7.8958   Third  NaN  Southampton       no
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
#
#      alone  sample  survived_num  age_bucket
# ...

# %% [markdown]
# <h3>Handling Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sex           891 non-null    object
#  1   age           714 non-null    float64
#  2   sibsp         891 non-null    int64
#  3   parch         891 non-null    int64
#  4   fare          891 non-null    float64
#  5   pclass        891 non-null    category
#  6   deck          203 non-null    category
#  7   embark_town   889 non-null    object
#  8   survived      891 non-null    object
#  9   alone         891 non-null    bool
#  10  sample        891 non-null    int64
#  11  survived_num  891 non-null    int64
#  12  age_bucket    714 non-null    float64
# dtypes: bool(1), category(2), float64(3), int64(4), object(3)
# memory usage: 72.8+ KB

# %%
#drop rows with any missing
df.dropna()
# Out:
#         sex   age  sibsp  parch     fare pclass deck  embark_town survived  \
# 1    female  38.0      1      0  71.2833  First    C    Cherbourg      yes
# 3    female  35.0      1      0  53.1000  First    C  Southampton      yes
# 6      male  54.0      0      0  51.8625  First    E  Southampton       no
# 10   female   4.0      1      1  16.7000  Third    G  Southampton      yes
# 11   female  58.0      0      0  26.5500  First    C  Southampton      yes
# ..      ...   ...    ...    ...      ...    ...  ...          ...      ...
# 871  female  47.0      1      1  52.5542  First    D  Southampton      yes
# 872    male  33.0      0      0   5.0000  First    B  Southampton       no
# 879  female  56.0      0      1  83.1583  First    C    Cherbourg      yes
# 887  female  19.0      0      0  30.0000  First    B  Southampton      yes
# 889    male  26.0      0      0  30.0000  First    C    Cherbourg      yes
#
#      alone  sample  survived_num  age_bucket
# ...

# %%
#drop rows with certain missing
df.dropna(subset='embark_town')
# Out:
#         sex   age  sibsp  parch     fare  pclass deck  embark_town survived  \
# 0      male  22.0      1      0   7.2500   Third  NaN  Southampton       no
# 1    female  38.0      1      0  71.2833   First    C    Cherbourg      yes
# 2    female  26.0      0      0   7.9250   Third  NaN  Southampton      yes
# 3    female  35.0      1      0  53.1000   First    C  Southampton      yes
# 4      male  35.0      0      0   8.0500   Third  NaN  Southampton       no
# ..      ...   ...    ...    ...      ...     ...  ...          ...      ...
# 886    male  27.0      0      0  13.0000  Second  NaN  Southampton       no
# 887  female  19.0      0      0  30.0000   First    B  Southampton      yes
# 888  female   NaN      1      2  23.4500   Third  NaN  Southampton       no
# 889    male  26.0      0      0  30.0000   First    C    Cherbourg      yes
# 890    male  32.0      0      0   7.7500   Third  NaN   Queenstown       no
#
#      alone  sample  survived_num  age_bucket
# ...

# %%
df['age'].fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].fillna(df.age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# <h3>Applying Functions to Data

# %%
df['fare'] + 5
# Out:
# 0      12.2500
# 1      76.2833
# 2      12.9250
# 3      58.1000
# 4      13.0500
#         ...
# 886    18.0000
# 887    35.0000
# 888    28.4500
# 889    35.0000
# 890    12.7500
# Name: fare, Length: 891, dtype: float64

# %%
# x**2 + 7x + 3x**3 + 5

# %%
df['fare']**2 + 7*df['fare'] + 3*df['fare']**3 + 5
# Out:
# 0      1.251547e+03
# 1      1.092223e+06
# 2      1.616484e+03
# 3      4.523602e+05
# 4      1.691133e+03
#            ...
# 886    6.856000e+03
# 887    8.211500e+04
# 888    3.940469e+04
# 889    8.211500e+04
# 890    1.515766e+03
# Name: fare, Length: 891, dtype: float64

# %%
x
# Out:
# 5

# %%
def my_function(x):

  return x**2 + 7*x + 3*x**3 + 5

# %%
my_function(5)
# Out:
# 440

# %%
df['fare'].apply(my_function)
# Out:
# 0      1.251547e+03
# 1      1.092223e+06
# 2      1.616484e+03
# 3      4.523602e+05
# 4      1.691133e+03
#            ...
# 886    6.856000e+03
# 887    8.211500e+04
# 888    3.940469e+04
# 889    8.211500e+04
# 890    1.515766e+03
# Name: fare, Length: 891, dtype: float64

# %%
df['fare'].apply(lambda x: x**2 + 7*x + 3*x**3 + 5)
# Out:
# 0      1.251547e+03
# 1      1.092223e+06
# 2      1.616484e+03
# 3      4.523602e+05
# 4      1.691133e+03
#            ...
# 886    6.856000e+03
# 887    8.211500e+04
# 888    3.940469e+04
# 889    8.211500e+04
# 890    1.515766e+03
# Name: fare, Length: 891, dtype: float64

# %%
df['fare'].apply(lambda x: my_function(x) - 5)
# Out:
# 0      1.246547e+03
# 1      1.092218e+06
# 2      1.611484e+03
# 3      4.523552e+05
# 4      1.686133e+03
#            ...
# 886    6.851000e+03
# 887    8.211000e+04
# 888    3.939969e+04
# 889    8.211000e+04
# 890    1.510766e+03
# Name: fare, Length: 891, dtype: float64

# %%
df[['age','fare']].apply(my_function)
# Out:
#           age          fare
# 0     32587.0  1.251547e+03
# 1    166331.0  1.092223e+06
# 2     53591.0  1.616484e+03
# 3    130100.0  4.523602e+05
# 4    130100.0  1.691133e+03
# ..        ...           ...
# 886   59972.0  6.856000e+03
# 887   21076.0  8.211500e+04
# 888       NaN  3.940469e+04
# 889   53591.0  8.211500e+04
# 890   99557.0  1.515766e+03
#
# [891 rows x 2 columns]

# %%
df['embark_town'][0][0]
# Out:
# 'S'

# %%
df = df.dropna(subset='embark_town')

# %%
df['embark_town'].map(lambda x: x[0])
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embark_town, Length: 889, dtype: object

# %%
df['embark_town'].map(lambda x: x.lower())
# Out:
# 0      southampton
# 1        cherbourg
# 2      southampton
# 3      southampton
# 4      southampton
#           ...
# 886    southampton
# 887    southampton
# 888    southampton
# 889      cherbourg
# 890     queenstown
# Name: embark_town, Length: 889, dtype: object

# %% [markdown]
# <h3>Selecting Only Columns of a Certain Type

# %%
df.select_dtypes(include=['float','int'])
# Out:
#       age  sibsp  parch     fare  sample  survived_num  age_bucket
# 0    22.0      1      0   7.2500       8             0        20.0
# 1    38.0      1      0  71.2833       8             1        30.0
# 2    26.0      0      0   7.9250       8             1        20.0
# 3    35.0      1      0  53.1000       8             1        30.0
# 4    35.0      0      0   8.0500       8             0        30.0
# ..    ...    ...    ...      ...     ...           ...         ...
# 886  27.0      0      0  13.0000       8             0        20.0
# 887  19.0      0      0  30.0000       8             1        10.0
# 888   NaN      1      2  23.4500       8             0         NaN
# 889  26.0      0      0  30.0000       8             1        20.0
# 890  32.0      0      0   7.7500       8             0        30.0
#
# [889 rows x 7 columns]

# %%
df.select_dtypes(include=['float','int']).apply(my_function)
# Out:
#           age  sibsp  parch          fare  sample  survived_num  age_bucket
# 0     32587.0     16      5  1.251547e+03    1661             5     24545.0
# 1    166331.0     16      5  1.092223e+06    1661            16     82115.0
# 2     53591.0      5      5  1.616484e+03    1661            16     24545.0
# 3    130100.0     16      5  4.523602e+05    1661            16     82115.0
# 4    130100.0      5      5  1.691133e+03    1661             5     82115.0
# ..        ...    ...    ...           ...     ...           ...         ...
# 886   59972.0      5      5  6.856000e+03    1661             5     24545.0
# 887   21076.0      5      5  8.211500e+04    1661            16      3175.0
# 888       NaN     16     47  3.940469e+04    1661             5         NaN
# 889   53591.0      5      5  8.211500e+04    1661            16     24545.0
# 890   99557.0      5      5  1.515766e+03    1661             5     82115.0
#
# [889 rows x 7 columns]

# %% [markdown]
# <h3>Re Ordering Columns

# %%
df.columns.tolist()
# Out:
# ['sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'pclass',
#  'deck',
#  'embark_town',
#  'survived',
#  'alone',
#  'sample',
#  'survived_num',
#  'age_bucket']

# %%
df[['age','survived','alone','age_bucket']]
# Out:
#       age survived  alone  age_bucket
# 0    22.0       no  False        20.0
# 1    38.0      yes  False        30.0
# 2    26.0      yes   True        20.0
# 3    35.0      yes  False        30.0
# 4    35.0       no   True        30.0
# ..    ...      ...    ...         ...
# 886  27.0       no   True        20.0
# 887  19.0      yes   True        10.0
# 888   NaN       no  False         NaN
# 889  26.0      yes   True        20.0
# 890  32.0       no   True        30.0
#
# [889 rows x 4 columns]

# %% [markdown]
# <h3>Printing two values together

# %%
def print_statement(x):
  return 'Passenger fare is: ' + str(x['fare']) + ' and class is ' + x['pclass']

# %%
df.apply(print_statement, axis=1)
# Out:
# 0         Passenger fare is: 7.25 and class is Third
# 1      Passenger fare is: 71.2833 and class is First
# 2        Passenger fare is: 7.925 and class is Third
# 3         Passenger fare is: 53.1 and class is First
# 4         Passenger fare is: 8.05 and class is Third
#                            ...
# 886      Passenger fare is: 13.0 and class is Second
# 887       Passenger fare is: 30.0 and class is First
# 888      Passenger fare is: 23.45 and class is Third
# 889       Passenger fare is: 30.0 and class is First
# 890       Passenger fare is: 7.75 and class is Third
# Length: 889, dtype: object

# %%
def multi_column_function(x):
  return x['fare']**2 + x['age']

# %%
df.apply(multi_column_function, axis=1)
# Out:
# 0        74.562500
# 1      5119.308859
# 2        88.805625
# 3      2854.610000
# 4        99.802500
#           ...
# 886     196.000000
# 887     919.000000
# 888            NaN
# 889     926.000000
# 890      92.062500
# Length: 889, dtype: float64

# %%
df[['fare','pclass']]
# Out:
#         fare  pclass
# 0     7.2500   Third
# 1    71.2833   First
# 2     7.9250   Third
# 3    53.1000   First
# 4     8.0500   Third
# ..       ...     ...
# 886  13.0000  Second
# 887  30.0000   First
# 888  23.4500   Third
# 889  30.0000   First
# 890   7.7500   Third
#
# [889 rows x 2 columns]

# %%
df[['fare','pclass']].apply(lambda x: print(x), axis=1)
# Out:
# fare       7.25
# pclass    Third
# Name: 0, dtype: object
# fare      71.2833
# pclass      First
# Name: 1, dtype: object
# fare      7.925
# pclass    Third
# Name: 2, dtype: object
# fare       53.1
# pclass    First
# Name: 3, dtype: object
# fare       8.05
# pclass    Third
# Name: 4, dtype: object
# fare      8.4583
# pclass     Third
# Name: 5, dtype: object
# fare      51.8625
# pclass      First
# Name: 6, dtype: object
# fare      21.075
# pclass     Third
# Name: 7, dtype: object
# fare      11.1333
# pclass      Third
# Name: 8, dtype: object
# fare      30.0708
# pclass     Second
# Name: 9, dtype: object
# fare       16.7
# pclass    Third
# Name: 10, dtype: object
# fare      26.55
# pclass    First
# Name: 11, dtype: object
# fare       8.05
# pclass    Third
# Name: 12, dtype: object
# fare      31.275
# pclass     Third
# Name: 13, dtype: object
# fare      7.8542
# pclass     Third
# Name: 14, dtype: object
# fare        16.0
# pclass    Second
# ...
